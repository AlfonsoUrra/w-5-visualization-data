# %%
# %pip install plotly

import plotly.express as px
import pandas as pd
import re
import seaborn as sns
import requests
from tqdm import tqdm
import sqlite3
# Out:
# Requirement already satisfied: plotly in c:\users\usuario\anaconda3\lib\site-packages (5.13.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from plotly) (8.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load the data

# %% [markdown]
# ### Health

# %%
#Cargar los datos del csv health
df_hnp = pd.read_csv('HNP_StatsData Alfonso.csv')

# %% [markdown]
# ### CO2

# %%
#Cargar los datos del csv co2
df_co2 = pd.read_csv('owid-co2-data.csv')

# %% [markdown]
# ## Data preprocessing

# %%
df_co2.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0             NaN      NaN                 NaN            NaN
# 1             NaN      NaN                 NaN            NaN
# 2             NaN      NaN                 NaN            NaN
# 3             NaN      NaN                 NaN            NaN
# 4             NaN      NaN                 NaN            NaN
#
#    nitrous_oxide_per_capita  population           gdp  \
# 0                       NaN   7624058.0           NaN
# 1                       NaN   7752117.0  9.421400e+09
# 2                       NaN   7840151.0  9.692280e+09
# 3                       NaN   7935996.0  1.001732e+10
# 4                       NaN   8039684.0  1.063052e+10
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                         NaN                NaN             NaN
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3                         NaN                NaN             NaN
# 4                         NaN                NaN             NaN
#
# [5 rows x 58 columns]

# %%
df_hnp.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL
# 2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL
# 3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS
# 4        Adults (ages 15-49) newly infected with HIV     SH.HIV.INCD
#
#          1960        1961        1962        1963        1964        1965  \
# 0  141.457567  141.603817  141.796749  141.651778  141.595374  141.593273
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    ...        2013        2014        2015       2016       2017       2018  \
# 0  ...  103.629032  101.905042  100.133826  98.367869  96.574004  95.011793
# 1  ...         NaN         NaN         NaN        NaN        NaN        NaN
# 2  ...         NaN         NaN         NaN        NaN        NaN        NaN
# 3  ...         NaN         NaN         NaN        NaN        NaN        NaN
# 4  ...         NaN         NaN         NaN        NaN        NaN        NaN
#
#        2019       2020  2021  Unnamed: 66
# 0  93.43222  91.845198   NaN          NaN
# 1       NaN        NaN   NaN          NaN
# 2       NaN        NaN   NaN          NaN
# 3       NaN        NaN   NaN          NaN
# 4       NaN        NaN   NaN          NaN
#
# [5 rows x 67 columns]

# %%
# Hago una primera limpieza del dataframe: elimino la columna 66, cambio el formato de long a tall.
#Convierto las columnas en filas con el método melt. Primer parámetro las columnas que quiero mantener, y toma el resto por defecto para pasarlas a filas, renombro esa variable con year.
df_hnp = df_hnp.drop(columns='Unnamed: 66')\
    .melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'])\
    .rename({'variable': 'Year'}, axis=1)

# %%
df_hnp.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name  Indicator Code  Year  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT  1960
# 1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL  1960
# 2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL  1960
# 3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS  1960
# 4        Adults (ages 15-49) newly infected with HIV     SH.HIV.INCD  1960
#
#         value
# 0  141.457567
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#una máscara booleana que obtiene las filas que contengan el strong 'gdp'
mask = df_hnp['Indicator Name'].str.contains('gdp', flags=re.IGNORECASE)

# %%
#Filtro el dataframe por las filas que complan la condición, y hago un copy para preservar los datos originales
df_hnp = df_hnp[mask].copy()

# %%
#encontrar valores únicos de indicator con el string clave 'gdp'
df_hnp['Indicator Name'].unique()
# Out:
# array(['Capital health expenditure (% of GDP)',
#        'Current health expenditure (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Public spending on education, total (% of GDP)'], dtype=object)

# %%
df_co2.head()
# Out:
#   iso_code      country  year    co2  consumption_co2  co2_growth_prct  \
# 0      AFG  Afghanistan  1949  0.015              NaN              NaN
# 1      AFG  Afghanistan  1950  0.084              NaN            475.0
# 2      AFG  Afghanistan  1951  0.092              NaN              8.7
# 3      AFG  Afghanistan  1952  0.092              NaN              0.0
# 4      AFG  Afghanistan  1953  0.106              NaN             16.0
#
#    co2_growth_abs  trade_co2  co2_per_capita  consumption_co2_per_capita  ...  \
# 0             NaN        NaN           0.002                         NaN  ...
# 1           0.070        NaN           0.011                         NaN  ...
# 2           0.007        NaN           0.012                         NaN  ...
# 3           0.000        NaN           0.012                         NaN  ...
# 4           0.015        NaN           0.013                         NaN  ...
#
#    ghg_per_capita  methane  methane_per_capita  nitrous_oxide  \
# 0             NaN      NaN                 NaN            NaN
# 1             NaN      NaN                 NaN            NaN
# 2             NaN      NaN                 NaN            NaN
# 3             NaN      NaN                 NaN            NaN
# 4             NaN      NaN                 NaN            NaN
#
#    nitrous_oxide_per_capita  population           gdp  \
# 0                       NaN   7624058.0           NaN
# 1                       NaN   7752117.0  9.421400e+09
# 2                       NaN   7840151.0  9.692280e+09
# 3                       NaN   7935996.0  1.001732e+10
# 4                       NaN   8039684.0  1.063052e+10
#
#    primary_energy_consumption  energy_per_capita  energy_per_gdp
# 0                         NaN                NaN             NaN
# 1                         NaN                NaN             NaN
# 2                         NaN                NaN             NaN
# 3                         NaN                NaN             NaN
# 4                         NaN                NaN             NaN
#
# [5 rows x 58 columns]

# %%
#filtro por columnas los string que quiero encontrar en el Dataframe
df_co2 = df_co2.filter(regex='gdp|iso_code|year|country').copy()

# %%
df_co2.head()
# Out:
#   iso_code      country  year  co2_per_gdp  consumption_co2_per_gdp  \
# 0      AFG  Afghanistan  1949          NaN                      NaN
# 1      AFG  Afghanistan  1950        0.009                      NaN
# 2      AFG  Afghanistan  1951        0.010                      NaN
# 3      AFG  Afghanistan  1952        0.009                      NaN
# 4      AFG  Afghanistan  1953        0.010                      NaN
#
#             gdp  energy_per_gdp
# 0           NaN             NaN
# 1  9.421400e+09             NaN
# 2  9.692280e+09             NaN
# 3  1.001732e+10             NaN
# 4  1.063052e+10             NaN

# %% [markdown]
# ## Merge the data

# %%
#convierto las columnas en filas, poniendo el foco en las que me interesan para el merge
df_co2 = df_co2.melt(id_vars=['iso_code', 'country', 'year'])

# %%
df_co2.head()
# Out:
#   iso_code      country  year     variable  value
# 0      AFG  Afghanistan  1949  co2_per_gdp    NaN
# 1      AFG  Afghanistan  1950  co2_per_gdp  0.009
# 2      AFG  Afghanistan  1951  co2_per_gdp  0.010
# 3      AFG  Afghanistan  1952  co2_per_gdp  0.009
# 4      AFG  Afghanistan  1953  co2_per_gdp  0.010

# %%
#renombro la columna variable
df_co2 = df_co2.rename({"variable": 'indicator'}, axis=1)

# %%
#elimino columna que me sobra
df_hnp = df_hnp.drop(columns='Indicator Code')

# %%
# asigno una lista de nuevos nombres de columna para mejorar la legibilidad del código 
df_hnp.columns = ['country', 'iso_code', 'indicator', 'year', 'value']

# %%
df_hnp.head()
# Out:
#                          country iso_code  \
# 68   Africa Eastern and Southern      AFE
# 98   Africa Eastern and Southern      AFE
# 108  Africa Eastern and Southern      AFE
# 385  Africa Eastern and Southern      AFE
# 511   Africa Western and Central      AFW
#
#                                              indicator  year  value
# 68               Capital health expenditure (% of GDP)  1960    NaN
# 98               Current health expenditure (% of GDP)  1960    NaN
# 108  Domestic general government health expenditure...  1960    NaN
# 385     Public spending on education, total (% of GDP)  1960    NaN
# 511              Capital health expenditure (% of GDP)  1960    NaN

# %%
#combino mis dos dataframes añadiendo al segundo dataf las filas del primero
df = pd.concat([df_hnp, df_co2])

# %%
df.to_csv('data.csv', index=False)

# %%
df.head()
# Out:
#                          country iso_code  \
# 68   Africa Eastern and Southern      AFE
# 98   Africa Eastern and Southern      AFE
# 108  Africa Eastern and Southern      AFE
# 385  Africa Eastern and Southern      AFE
# 511   Africa Western and Central      AFW
#
#                                              indicator  year  value
# 68               Capital health expenditure (% of GDP)  1960    NaN
# 98               Current health expenditure (% of GDP)  1960    NaN
# 108  Domestic general government health expenditure...  1960    NaN
# 385     Public spending on education, total (% of GDP)  1960    NaN
# 511              Capital health expenditure (% of GDP)  1960    NaN

# %% [markdown]
# ## External sources

# %% [markdown]
# ### API

# %%
#extraigo los datos de la api
df_world_bank = pd.read_xml('https://api.worldbank.org/v2/source/75/indicators')

# %%
df_world_bank.head()
# Out:
#                id                     {http://www.worldbank.org}name  \
# 0  AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 1  AG.LND.FRST.ZS                       Forest area (% of land area)
# 2  AG.PRD.FOOD.XD            Food production index (2014-2016 = 100)
# 3          CC.EST                    Control of Corruption: Estimate
# 4  EG.CFT.ACCS.ZS  Access to clean fuels and technologies for coo...
#
#    {http://www.worldbank.org}unit  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                 {http://www.worldbank.org}source  \
# 0  Environment, Social and Governance (ESG) Data
# 1  Environment, Social and Governance (ESG) Data
# 2  Environment, Social and Governance (ESG) Data
# 3  Environment, Social and Governance (ESG) Data
# 4  Environment, Social and Governance (ESG) Data
#
#                 {http://www.worldbank.org}sourceNote  \
# 0  Agricultural land refers to the share of land ...
# 1  Forest area is land under natural or planted s...
# 2  Food production index covers food crops that a...
# 3  Control of Corruption captures perceptions of ...
# 4  Access to clean fuels and technologies for coo...
#
#         {http://www.worldbank.org}sourceOrganization  \
# 0  Food and Agriculture Organization, electronic ...
# 1  Food and Agriculture Organization, electronic ...
# 2  Food and Agriculture Organization, electronic ...
# 3  Detailed documentation of the WGI, interactive...
# 4  WHO Global Health Observatory  (https://www.wh...
#
#    {http://www.worldbank.org}topics
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN

# %%
#relizo solicitud a la api y la parseo con el método json y la almaceno
res = requests.get('https://api.worldbank.org/v2/country/all/indicator/AG.LND.FRST.ZS?format=json&date=1960:2020')

data = res.json()

# %%
list_df = []

# %%
#se está realizando un bucle "for" para solicitar y almacenar los datos de la API de Banco Mundial
#se ejecuta para un número de páginas igual a "data[0]['pages']+1
#Para cada página, se realiza una solicitud a la API con el método "get

for page in tqdm(range(1, data[0]['pages']+1)):
    res = requests.get(f'https://api.worldbank.org/v2/country/all/indicator/AG.LND.FRST.ZS?format=json&date=1960:2020&page={page}')
    data = res.json()
    df_data = pd.DataFrame(data[1:][0])
    list_df.append(df_data)
# Out:
# 100%|██████████| 325/325 [06:26<00:00,  1.19s/it]

# %%
#concatena todos los datos en un mismo dataframe
df_api = pd.concat(list_df)

# %%
df_api.head()
# Out:
#                                            indicator  \
# 0  {'id': 'AG.LND.FRST.ZS', 'value': 'Forest area...
# 1  {'id': 'AG.LND.FRST.ZS', 'value': 'Forest area...
# 2  {'id': 'AG.LND.FRST.ZS', 'value': 'Forest area...
# 3  {'id': 'AG.LND.FRST.ZS', 'value': 'Forest area...
# 4  {'id': 'AG.LND.FRST.ZS', 'value': 'Forest area...
#
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2020
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2019
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2018
# 3  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2017
# 4  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2016
#
#        value unit obs_status  decimal
# 0  30.174186                        1
# 1  30.391558                        1
# 2  30.611444                        1
# 3  30.824248                        1
# 4  31.039613                        1

# %%
#selecciono las columnas que me interesan
df_api = df_api[['countryiso3code', 'date', 'value']].copy()

# %%
#extrae el nombre del indicador de los datos.
indicator_name = list_df[0].loc[0, 'indicator']['value']
indicator_name
# Out:
# 'Forest area (% of land area)'

# %%
#reasingno el nombre de la columna indicator
df_api['indicator'] = indicator_name
indicator_name
# Out:
# 'Forest area (% of land area)'

# %%
df_api.head()
# Out:
#   countryiso3code  date      value                     indicator
# 0             AFE  2020  30.174186  Forest area (% of land area)
# 1             AFE  2019  30.391558  Forest area (% of land area)
# 2             AFE  2018  30.611444  Forest area (% of land area)
# 3             AFE  2017  30.824248  Forest area (% of land area)
# 4             AFE  2016  31.039613  Forest area (% of land area)

# %%
dic = {}

# %%
#crea un diccionario "dic" con claves que son códigos de país ISO y valores que son nombres de países.
for i,j in df[['country', 'iso_code']].value_counts().index:
    dic[j] = i

# %%
dic
# Out:
# {'GBR': 'United Kingdom',
#  'CAN': 'Canada',
#  'DEU': 'Germany',
#  'USA': 'United States',
#  'POL': 'Poland',
#  'BEL': 'Belgium',
#  'FRA': 'France',
#  'AUT': 'Austria',
#  'OWID_WRL': 'World',
#  'NOR': 'Norway',
#  'KAZ': 'Kazakhstan',
#  'BLR': 'Belarus',
#  'ESP': 'Spain',
#  'LVA': 'Latvia',
#  'LTU': 'Lithuania',
#  'AZE': 'Azerbaijan',
#  'ARM': 'Armenia',
#  'MDA': 'Moldova',
#  'TJK': 'Tajikistan',
#  'GEO': 'Georgia',
#  'TKM': 'Turkmenistan',
#  'UKR': 'Ukraine',
#  'UZB': 'Uzbekistan',
#  'HUN': 'Hungary',
#  'EST': 'Estonia',
#  'SWE': 'Sweden',
#  'DNK': 'Denmark',
#  'NLD': 'Netherlands',
#  'IRL': 'Ireland',
#  'CHE': 'Switzerland',
#  'ROU': 'Romania',
#  'IND': 'India',
#  'ITA': 'Italy',
#  'FIN': 'Finland',
#  'CZE': 'Czechia',
#  'AUS': 'Australia',
#  'GRC': 'Greece',
#  'JPN': 'Japan',
#  'PRT': 'Portugal',
#  'NZL': 'New Zealand',
#  'BGR': 'Bulgaria',
#  'ZAF': 'South Africa',
#  'PER': 'Peru',
#  'BIH': 'Bosnia and Herzegovina',
#  'HRV': 'Croatia',
#  'MKD': 'North Macedonia',
#  'MNE': 'Montenegro',
#  'SVN': 'Slovenia',
#  'SRB': 'Serbia',
#  'ARG': 'Argentina',
#  'IDN': 'Indonesia',
#  'MYS': 'Malaysia',
#  'MEX': 'Mexico',
#  'VNM': 'Vietnam',
#  'RUS': 'Russian Federation',
#  'KGZ': 'Kyrgyz Republic',
#  'CHL': 'Chile',
#  'CHN': 'China',
#  'BRA': 'Brazil',
#  'ZWE': 'Zimbabwe',
#  'PHL': 'Philippines',
#  'TTO': 'Trinidad and Tobago',
#  'NGA': 'Nigeria',
#  'TUN': 'Tunisia',
#  'DZA': 'Algeria',
#  'ECU': 'Ecuador',
#  'PRI': 'Puerto Rico',
#  'COL': 'Colombia',
#  'SVK': 'Slovak Republic',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'CUW': 'Curacao',
#  'ABW': 'Aruba',
#  'MOZ': 'Mozambique',
#  'IRQ': 'Iraq',
#  'TUR': 'Turkiye',
#  'BRB': 'Barbados',
#  'MAR': 'Morocco',
#  'MMR': 'Myanmar',
#  'BOL': 'Bolivia',
#  'ISR': 'Israel',
#  'LBN': 'Lebanon',
#  'THA': 'Thailand',
#  'URY': 'Uruguay',
#  'ALB': 'Albania',
#  'MDG': 'Madagascar',
#  'BHR': 'Bahrain',
#  'ISL': 'Iceland',
#  'SAU': 'Saudi Arabia',
#  'ERI': 'Eritrea',
#  'ETH': 'Ethiopia',
#  'CUB': 'Cuba',
#  'GTM': 'Guatemala',
#  'NIC': 'Nicaragua',
#  'LUX': 'Luxembourg',
#  'BGD': 'Bangladesh',
#  'KWT': 'Kuwait',
#  'PAK': 'Pakistan',
#  'DOM': 'Dominican Republic',
#  'PAN': 'Panama',
#  'QAT': 'Qatar',
#  'AFG': 'Afghanistan',
#  'SUR': 'Suriname',
#  'AGO': 'Angola',
#  'UGA': 'Uganda',
#  'JAM': 'Jamaica',
#  'KEN': 'Kenya',
#  'SOM': 'Somalia',
#  'SWZ': 'Eswatini',
#  'BLZ': 'Belize',
#  'GNQ': 'Equatorial Guinea',
#  'TON': 'Tonga',
#  'TGO': 'Togo',
#  'TZA': 'Tanzania',
#  'SLV': 'El Salvador',
#  'BMU': 'Bermuda',
#  'NCL': 'New Caledonia',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'CRI': 'Costa Rica',
#  'NPL': 'Nepal',
#  'CYP': 'Cyprus',
#  'SSD': 'South Sudan',
#  'DJI': 'Djibouti',
#  'SDN': 'Sudan',
#  'MWI': 'Malawi',
#  'MNG': 'Mongolia',
#  'MLT': 'Malta',
#  'LKA': 'Sri Lanka',
#  'SGP': 'Singapore',
#  'JOR': 'Jordan',
#  'SLE': 'Sierra Leone',
#  'PRY': 'Paraguay',
#  'GHA': 'Ghana',
#  'ZMB': 'Zambia',
#  'GRL': 'Greenland',
#  'GRD': 'Grenada',
#  'RWA': 'Rwanda',
#  'WSM': 'Samoa',
#  'GNB': 'Guinea-Bissau',
#  'GUY': 'Guyana',
#  'HTI': 'Haiti',
#  'CMR': 'Cameroon',
#  'HND': 'Honduras',
#  'BDI': 'Burundi',
#  'MUS': 'Mauritius',
#  'FJI': 'Fiji',
#  'PNG': 'Papua New Guinea',
#  'DMA': 'Dominica',
#  'STP': 'Sao Tome and Principe',
#  'SLB': 'Solomon Islands',
#  'PYF': 'French Polynesia',
#  'PLW': 'Palau',
#  'KHM': 'Cambodia',
#  'ATG': 'Antigua and Barbuda',
#  'BFA': 'Burkina Faso',
#  'CIV': "Cote d'Ivoire",
#  'GIN': 'Guinea',
#  'BEN': 'Benin',
#  'SEN': 'Senegal',
#  'NER': 'Niger',
#  'TWN': 'Taiwan',
#  'MLI': 'Mali',
#  'COM': 'Comoros',
#  'MRT': 'Mauritania',
#  'ARE': 'United Arab Emirates',
#  'CAF': 'Central African Republic',
#  'TCD': 'Chad',
#  'GAB': 'Gabon',
#  'KIR': 'Kiribati',
#  'VGB': 'British Virgin Islands',
#  'VUT': 'Vanuatu',
#  'SYC': 'Seychelles',
#  'NRU': 'Nauru',
#  'OMN': 'Oman',
#  'VEN': 'Venezuela, RB',
#  'KOR': 'Korea, Rep.',
#  'PRK': "Korea, Dem. People's Rep.",
#  'IRN': 'Iran, Islamic Rep.',
#  'BTN': 'Bhutan',
#  'MDV': 'Maldives',
#  'BWA': 'Botswana',
#  'EGY': 'Egypt, Arab Rep.',
#  'COD': 'Congo, Dem. Rep.',
#  'BES': 'Bonaire Sint Eustatius and Saba',
#  'TUV': 'Tuvalu',
#  'MHL': 'Marshall Islands',
#  'TCA': 'Turks and Caicos Islands',
#  'LSO': 'Lesotho',
#  'AND': 'Andorra',
#  'LIE': 'Liechtenstein',
#  'NAM': 'Namibia',
#  'SYR': 'Syrian Arab Republic',
#  'BRN': 'Brunei Darussalam',
#  'HKG': 'Hong Kong SAR, China',
#  'FRO': 'Faroe Islands',
#  'MTQ': 'Martinique',
#  'BHS': 'Bahamas, The',
#  'GUF': 'French Guiana',
#  'CPV': 'Cabo Verde',
#  'YEM': 'Yemen, Rep.',
#  'GLP': 'Guadeloupe',
#  'VCT': 'St. Vincent and the Grenadines',
#  'GMB': 'Gambia, The',
#  'SPM': 'Saint Pierre and Miquelon',
#  'LCA': 'St. Lucia',
#  'LAO': 'Lao PDR',
#  'PSE': 'Palestine',
#  'SSF': 'Sub-Saharan Africa',
#  'MAF': 'St. Martin (French part)',
#  'WLD': 'World',
#  'SMR': 'San Marino',
#  'KNA': 'Saint Kitts and Nevis',
#  'AFW': 'Africa Western and Central',
#  'SSA': 'Sub-Saharan Africa (excluding high income)',
#  'ASM': 'American Samoa',
#  'VIR': 'Virgin Islands (U.S.)',
#  'TSS': 'Sub-Saharan Africa (IDA & IBRD countries)',
#  'TLS': 'Timor',
#  'UMC': 'Upper middle income',
#  'TSA': 'South Asia (IDA & IBRD)',
#  'SAS': 'South Asia',
#  'ARB': 'Arab World',
#  'SST': 'Small states',
#  'LIC': 'Low income',
#  'ECS': 'Europe & Central Asia',
#  'EMU': 'Euro area',
#  'XKX': 'Kosovo',
#  'LTE': 'Late-demographic dividend',
#  'EAP': 'East Asia & Pacific (excluding high income)',
#  'LCN': 'Latin America & Caribbean',
#  'AFE': 'Africa Eastern and Southern',
#  'TLA': 'Latin America & the Caribbean (IDA & IBRD countries)',
#  'LDC': 'Least developed countries: UN classification',
#  'LMY': 'Low & middle income',
#  'TEC': 'Europe & Central Asia (IDA & IBRD countries)',
#  'ECA': 'Europe & Central Asia (excluding high income)',
#  'IMN': 'Isle of Man',
#  'EUU': 'European Union',
#  'FCS': 'Fragile and conflict affected situations',
#  'IDA': 'IDA total',
#  'IDX': 'IDA only',
#  'IDB': 'IDA blend',
#  'IBT': 'IDA & IBRD total',
#  'IBD': 'IBRD only',
#  'HIC': 'High income',
#  'HPC': 'Heavily indebted poor countries (HIPC)',
#  'GUM': 'Guam',
#  'GIB': 'Gibraltar',
#  'LMC': 'Lower middle income',
#  'LAC': 'Latin America & Caribbean (excluding high income)',
#  'MAC': 'Macao SAR, China',
#  'COG': 'Congo',
#  'CSS': 'Caribbean small states',
#  'PRE': 'Pre-demographic dividend',
#  'PST': 'Post-demographic dividend',
#  'CYM': 'Cayman Islands',
#  'CEB': 'Central Europe and the Baltics',
#  'CHI': 'Channel Islands',
#  'PSS': 'Pacific island small states',
#  'OSS': 'Other small states',
#  'OED': 'OECD members',
#  'INX': 'Not classified',
#  'MNP': 'Northern Mariana Islands',
#  'NAC': 'North America',
#  'TMN': 'Middle East & North Africa (IDA & IBRD countries)',
#  'MEA': 'Middle East & North Africa',
#  'TEA': 'East Asia & Pacific (IDA & IBRD countries)',
#  'EAS': 'East Asia & Pacific',
#  'EAR': 'Early-demographic dividend',
#  'MCO': 'Monaco',
#  'MIC': 'Middle income',
#  'MNA': 'Middle East & North Africa (excluding high income)',
#  'FSM': 'Micronesia, Fed. Sts.',
#  'MSR': 'Montserrat',
#  'SHN': 'Saint Helena',
#  'COK': 'Cook Islands',
#  'CXR': 'Christmas Island',
#  'NIU': 'Niue',
#  'ATA': 'Antarctica',
#  'MYT': 'Mayotte',
#  'AIA': 'Anguilla',
#  'OWID_KOS': 'Kosovo'}

# %%
#inserto una nueva columna "country" en el DataFrame "df_api".
#reemplazo los valores en la columna "countryiso3code" con sus correspondientes nombres de país utilizando el diccionario "dic".Toma un diccionario como argumento y utiliza los valores en este diccionario para reemplazar los valores en la columna especificada.
df_api.insert(0, 'country', df_api.countryiso3code.replace(dic))

# %%
#renombra las columnas "countryiso3code" y "date" en el DataFrame "df_api"
df_api = df_api.rename({'countryiso3code': 'iso_code', 'date': 'year'}, axis=1)

# %%
#uno los dos dataframes
df = pd.concat([df, df_api]).reset_index(drop=True)

# %%
df.head()
# Out:
#                        country iso_code  \
# 0  Africa Eastern and Southern      AFE
# 1  Africa Eastern and Southern      AFE
# 2  Africa Eastern and Southern      AFE
# 3  Africa Eastern and Southern      AFE
# 4   Africa Western and Central      AFW
#
#                                            indicator  year  value
# 0              Capital health expenditure (% of GDP)  1960    NaN
# 1              Current health expenditure (% of GDP)  1960    NaN
# 2  Domestic general government health expenditure...  1960    NaN
# 3     Public spending on education, total (% of GDP)  1960    NaN
# 4              Capital health expenditure (% of GDP)  1960    NaN

# %%
df['indicator'].unique()
# Out:
# array(['Capital health expenditure (% of GDP)',
#        'Current health expenditure (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Public spending on education, total (% of GDP)', 'co2_per_gdp',
#        'consumption_co2_per_gdp', 'gdp', 'energy_per_gdp',
#        'Forest area (% of land area)'], dtype=object)

# %%
df_api.head()
# Out:
#                        country iso_code  year      value  \
# 0  Africa Eastern and Southern      AFE  2020  30.174186
# 1  Africa Eastern and Southern      AFE  2019  30.391558
# 2  Africa Eastern and Southern      AFE  2018  30.611444
# 3  Africa Eastern and Southern      AFE  2017  30.824248
# 4  Africa Eastern and Southern      AFE  2016  31.039613
#
#                       indicator
# 0  Forest area (% of land area)
# 1  Forest area (% of land area)
# 2  Forest area (% of land area)
# 3  Forest area (% of land area)
# 4  Forest area (% of land area)

# %%
df[['country', 'iso_code']]
# Out:
#                             country iso_code
# 0       Africa Eastern and Southern      AFE
# 1       Africa Eastern and Southern      AFE
# 2       Africa Eastern and Southern      AFE
# 3       Africa Eastern and Southern      AFE
# 4        Africa Western and Central      AFW
# ...                             ...      ...
# 183005                     Zimbabwe      ZWE
# 183006                     Zimbabwe      ZWE
# 183007                     Zimbabwe      ZWE
# 183008                     Zimbabwe      ZWE
# 183009                     Zimbabwe      ZWE
#
# [183010 rows x 2 columns]

# %%
#lee una tabla HTML y almacena los datos en el DataFrame "df_iso".
df_iso = pd.read_html('https://cloford.com/resources/codes/index.htm')[3]

# %%
#crea una copia del DataFrame "df_iso" que solo incluye las columnas "Continent", "ISO (3)" y "Country".
df_iso = df_iso[['Continent', 'ISO (3)', 'Country']].copy()

# %%
#renombra para poder unir con el dataframe
df_iso.columns=['continent', 'iso_code', 'country']

# %%
#lo paso a csv
df.to_csv('data_all_indicators.csv', index=False)

# %%
#df.to_csv(r"C:\Users\Usuario\Desktop\Proyecto final\Indicators.csv", index=False)

# %%
#lo paso a csv
df_iso.to_csv('data_iso.csv', index=False)

# %%
#df_iso.to_csv(r"C:\Users\Usuario\Desktop\Proyecto final\ISO.csv", index=False)

# %%
df['year'] = df['year'].astype(int)

# %%
df.head()
# Out:
#                        country iso_code  \
# 0  Africa Eastern and Southern      AFE
# 1  Africa Eastern and Southern      AFE
# 2  Africa Eastern and Southern      AFE
# 3  Africa Eastern and Southern      AFE
# 4   Africa Western and Central      AFW
#
#                                            indicator  year  value
# 0              Capital health expenditure (% of GDP)  1960    NaN
# 1              Current health expenditure (% of GDP)  1960    NaN
# 2  Domestic general government health expenditure...  1960    NaN
# 3     Public spending on education, total (% of GDP)  1960    NaN
# 4              Capital health expenditure (% of GDP)  1960    NaN

# %% [markdown]
# # Ponerlo en SQL

# %%
#conecto a una base de datos SQLite.

con = sqlite3.connect('database.db')

# %%
#guardando "df_iso" en una tabla de la base de datos SQLite "iso"
df_iso.to_sql('iso', con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9056/3912011997.py in <module>
#       1 #guardando "df_iso" en una tabla de la base de datos SQLite "iso"
# ----> 2 df_iso.to_sql('iso', con)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2870         from pandas.io import sql
#    2871
# -> 2872         sql.to_sql(
#    2873             self,
#    2874             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     715         )
#     716
# --> 717     pandas_sql.to_sql(
#     718         frame,
#     719         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2223             dtype=dtype,
#    2224         )
# -> 2225         table.create()
#    2226         table.insert(chunksize, method)
#    2227
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'iso' already exists.

# %%
#guardando "df" en una tabla de la base de datos SQLite "iso"

df.to_sql('indicator_data', con)

# %%
#Esta consulta hace una combinación de dos tablas: "indicator_data" y "iso"
query = '''
SELECT *
FROM indicator_data
INNER JOIN iso
ON indicator_data.iso_code = iso.iso_code
'''

# %%
pd.read_sql(sql=query, con=con).head()

# %%
fig = px.line(data_frame=df, x='year', y='value', facet_col='indicator', color='iso_code')

# %%
fig.update_yaxes(matches=None)
fig.update_xaxes(tickangle=45)
fig.for_each_annotation(lambda annotation: annotation.update(textangle=22))

# %%
dff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17740/2703340203.py in <module>
# ----> 1 dff
#
# NameError: name 'dff' is not defined

# %%
dff = df.pivot_table(index=['country', 'iso_code', 'year'], columns='indicator', values='value')

# %%
dff.reset_index()
# Out:
# indicator   country iso_code  year  Capital health expenditure (% of GDP)  \
# 0                             1960                                    NaN
# 1                             1961                                    NaN
# 2                             1962                                    NaN
# 3                             1963                                    NaN
# 4                             1964                                    NaN
# ...             ...      ...   ...                                    ...
# 27990      Zimbabwe      ZWE  2017                               0.073545
# 27991      Zimbabwe      ZWE  2018                               0.271347
# 27992      Zimbabwe      ZWE  2019                               0.000000
# 27993      Zimbabwe      ZWE  2020                               0.000000
# 27994      Zimbabwe      ZWE  2021                               0.000000
#
# indicator  Current health expenditure (% of GDP)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 27990                                   7.469752
# 27991                                   8.680062
# 27992                                   7.703565
# 27993                                   0.000000
# 27994                                   0.000000
#
# indicator  Domestic general government health expenditure (% of GDP)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
# ...                                                      ...
# 27990                                               1.794181
# 27991                                               2.782935
# 27992                                               1.358270
# 27993                                               0.000000
# 27994                                               0.000000
#
# indicator  Forest area (% of land area)  \
# 0                              0.000000
# 1                              0.000000
# 2                              0.000000
# 3                              0.000000
# 4                              0.000000
# ...                                 ...
# 27990                         45.451183
# 27991                         45.332093
# 27992                         45.213002
# 27993                         45.093912
# 27994                               NaN
#
# indicator  Public spending on education, total (% of GDP)  co2_per_gdp  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 27990                                             5.81878        0.437
# 27991                                             3.86611        0.522
# 27992                                             0.00000        0.000
# 27993                                             0.00000        0.000
# 27994                                             0.00000          NaN
#
# indicator  consumption_co2_per_gdp  energy_per_gdp           gdp
# 0                              NaN             NaN           NaN
# 1                              NaN             NaN           NaN
# 2                              NaN             NaN           NaN
# 3                              NaN             NaN           NaN
# 4                              NaN             NaN           NaN
# ...                            ...             ...           ...
# 27990                        0.512             0.0  2.194784e+10
# 27991                        0.580             0.0  2.271535e+10
# 27992                        0.000             0.0  0.000000e+00
# 27993                        0.000             0.0  0.000000e+00
# 27994                          NaN             NaN           NaN
#
# [27995 rows x 12 columns]

# %%
dff.columns
# Out:
# Index(['Capital health expenditure (% of GDP)',
#        'Current health expenditure (% of GDP)',
#        'Domestic general government health expenditure (% of GDP)',
#        'Forest area (% of land area)',
#        'Public spending on education, total (% of GDP)', 'co2_per_gdp',
#        'consumption_co2_per_gdp', 'energy_per_gdp', 'gdp'],
#       dtype='object', name='indicator')

# %%
#dff.to_csv(r"C:\Users\Usuario\Desktop\Proyecto final\ETL1.csv", index=False)

# %%
df_api.head()
# Out:
#                        country iso_code  year      value  \
# 0  Africa Eastern and Southern      AFE  2020  30.174186
# 1  Africa Eastern and Southern      AFE  2019  30.391558
# 2  Africa Eastern and Southern      AFE  2018  30.611444
# 3  Africa Eastern and Southern      AFE  2017  30.824248
# 4  Africa Eastern and Southern      AFE  2016  31.039613
#
#                       indicator
# 0  Forest area (% of land area)
# 1  Forest area (% of land area)
# 2  Forest area (% of land area)
# 3  Forest area (% of land area)
# 4  Forest area (% of land area)

# %%
df_co2.head()
# Out:
#   iso_code      country  year    indicator  value
# 0      AFG  Afghanistan  1949  co2_per_gdp    NaN
# 1      AFG  Afghanistan  1950  co2_per_gdp  0.009
# 2      AFG  Afghanistan  1951  co2_per_gdp  0.010
# 3      AFG  Afghanistan  1952  co2_per_gdp  0.009
# 4      AFG  Afghanistan  1953  co2_per_gdp  0.010

# %%
df_hnp.head()
# Out:
#                          country iso_code  \
# 68   Africa Eastern and Southern      AFE
# 98   Africa Eastern and Southern      AFE
# 108  Africa Eastern and Southern      AFE
# 385  Africa Eastern and Southern      AFE
# 511   Africa Western and Central      AFW
#
#                                              indicator  year  value
# 68               Capital health expenditure (% of GDP)  1960    NaN
# 98               Current health expenditure (% of GDP)  1960    NaN
# 108  Domestic general government health expenditure...  1960    NaN
# 385     Public spending on education, total (% of GDP)  1960    NaN
# 511              Capital health expenditure (% of GDP)  1960    NaN

# %% [markdown]
# ---

# %%
df_iso.head()
# Out:
#   continent iso_code         country
# 0      Asia      AFG     Afghanistan
# 1    Europe      ALB         Albania
# 2    Africa      DZA         Algeria
# 3   Oceania      ASM  American Samoa
# 4    Europe      AND         Andorra

# %%
df_country = df.loc[df['country'].isin(['Spain','Morocco','Brazil','Canada','Mexico','Australia','Pakistan', 'India', 'Russia', 'Chile', 'Germany', 'Vietnam', 'China', 'Thailand', 'Egypt', 'Italy', 'Finland', 'United States'])]
df_coun_year = df_country[(df_country['year'] > 1990) & (df_country['year'] < 2018)]

# %%
df['country'].unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle East & North Africa (IDA & IBRD countries)',
#        'Middle income', 'North America', 'Not classified', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Upper middle income',
#        'World', 'Afghanistan', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The',
#        'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Faroe Islands', 'Fiji',
#        'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia, The',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland',
#        'Grenada', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras', 'Hong Kong SAR, China', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran, Islamic Rep.', 'Iraq',
#        'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Dem. People's Rep.", 'Korea, Rep.', 'Kosovo', 'Kuwait',
#        'Kyrgyz Republic', 'Lao PDR', 'Latvia', 'Lebanon', 'Lesotho',
#        'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg',
#        'Macao SAR, China', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives',
#        'Mali', 'Malta', 'Marshall Islands', 'Mauritania', 'Mauritius',
#        'Mexico', 'Micronesia, Fed. Sts.', 'Moldova', 'Monaco', 'Mongolia',
#        'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'North Macedonia',
#        'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Romania',
#        'Russian Federation', 'Rwanda', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
#        'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovak Republic', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South Sudan',
#        'Spain', 'Sri Lanka', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Martin (French part)', 'St. Vincent and the Grenadines',
#        'Sudan', 'Suriname', 'Sweden', 'Switzerland',
#        'Syrian Arab Republic', 'Tajikistan', 'Tanzania', 'Thailand',
#        'Timor-Leste', 'Togo', 'Tonga', 'Trinidad and Tobago', 'Tunisia',
#        'Turkiye', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu',
#        'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela, RB', 'Vietnam', 'Virgin Islands (U.S.)',
#        'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe',
#        'Africa', 'Anguilla', 'Antarctica', 'Asia',
#        'Asia (excl. China & India)', 'Bahamas',
#        'Bonaire Sint Eustatius and Saba', 'Brunei', 'Cape Verde',
#        'Christmas Island', 'Congo', 'Cook Islands',
#        'Democratic Republic of Congo', 'EU-27', 'EU-28', 'Egypt',
#        'Europe', 'Europe (excl. EU-27)', 'Europe (excl. EU-28)',
#        'Faeroe Islands', 'French Equatorial Africa', 'French Guiana',
#        'French West Africa', 'Gambia', 'Guadeloupe', 'Hong Kong',
#        'International transport', 'Iran', 'Kuwaiti Oil Fires',
#        'Kyrgyzstan', 'Laos', 'Leeward Islands', 'Macao', 'Martinique',
#        'Mayotte', 'Micronesia', 'Micronesia (country)', 'Montserrat',
#        'Niue', 'North America (excl. USA)', 'North Korea', 'Oceania',
#        'Palestine', 'Panama Canal Zone', 'Reunion', 'Russia',
#        'Ryukyu Islands', 'Saint Helena', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Slovakia', 'South America',
#        'South Korea', 'St. Kitts-Nevis-Anguilla', 'Syria', 'Taiwan',
#        'Timor', 'Turkey', 'Venezuela', 'Wallis and Futuna', 'Yemen', ''],
#       dtype=object)

# %%
df_coun_year['value'] = df['value'].fillna(0)
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9056/923738176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_coun_year['value'] = df['value'].fillna(0)

# %%
#df_coun_year.to_csv(r"C:\Users\Usuario\Desktop\Proyecto final\Data_visual.csv", index=False)

# %%
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9056/3905340741.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_coun_year['value'] = df['value'].fillna(0)

# %%
# Out:
#                             country iso_code  \
# 0       Africa Eastern and Southern      AFE
# 1       Africa Eastern and Southern      AFE
# 2       Africa Eastern and Southern      AFE
# 3       Africa Eastern and Southern      AFE
# 4        Africa Western and Central      AFW
# ...                             ...      ...
# 183005                     Zimbabwe      ZWE
# 183006                     Zimbabwe      ZWE
# 183007                     Zimbabwe      ZWE
# 183008                     Zimbabwe      ZWE
# 183009                     Zimbabwe      ZWE
#
#                                                 indicator  year  value
# 0                   Capital health expenditure (% of GDP)  1960    0.0
# 1                   Current health expenditure (% of GDP)  1960    0.0
# 2       Domestic general government health expenditure...  1960    0.0
# 3          Public spending on education, total (% of GDP)  1960    0.0
# 4                   Capital health expenditure (% of GDP)  1960    0.0
# ...                                                   ...   ...    ...
# 183005                       Forest area (% of land area)  1964    0.0
# 183006                       Forest area (% of land area)  1963    0.0
# 183007                       Forest area (% of land area)  1962    0.0
# 183008                       Forest area (% of land area)  1961    0.0
# 183009                       Forest area (% of land area)  1960    0.0
#
# [183010 rows x 5 columns]

# %%
df_sea = pd.read_csv(r'..data\seaice.csv')

# %%
df_sea = df_sea[df_sea['Year'] > 1990]

# %%
df_sea.columns
# Out:
# Index(['Year', ' Month', ' Day', '     Extent', '    Missing', ' Source Data',
#        'hemisphere'],
#       dtype='object')

# %%
df_sea = df_sea.drop(columns=[' Month', ' Day', '    Missing', ' Source Data'])

# %%
df_sea
# Out:
#        Year       Extent hemisphere
# 2799   1991       13.634      north
# 2800   1991       13.831      north
# 2801   1991       13.847      north
# 2802   1991       13.858      north
# 2803   1991       13.872      north
# ...     ...          ...        ...
# 26349  2019       10.085      south
# 26350  2019       10.078      south
# 26351  2019       10.219      south
# 26352  2019       10.363      south
# 26353  2019       10.436      south
#
# [20756 rows x 3 columns]

# %%
df_temp = pd.read_csv(r"..data\GlobalLandTemperaturesByCountry.csv")

# %%
df_temp = df_temp[df_temp['dt'] > '1990-01-01']

# %%
df_temp['dt'] = pd.to_datetime(df_temp['dt'])
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_9056/710794200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['dt'] = pd.to_datetime(df_temp['dt'])

# %%
df_temp = df_temp.groupby([df_temp['dt'].dt.year, 'Country'])['AverageTemperature'].mean().reset_index()

# %%
df_temp = df_temp.rename(columns={'dt': 'year'})
df_temp = df_temp.rename(columns={'Country': 'country'})

# %%
#df_sea.to_csv(r"..data\sea.csv", index=False)
#df_temp.to_csv(r"..data\temp.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17740/24031339.py in <module>
# ----> 1 df_sea.to_csv(r"..data\sea.csv", index=False)
#       2 df_temp.to_csv(r"..data\temp.csv", index=False)
#
# NameError: name 'df_sea' is not defined

# %%
df_temp
# Out:
#       year         country  AverageTemperature
# 0     1990     Afghanistan           16.214727
# 1     1990          Africa           25.002091
# 2     1990         Albania           14.483091
# 3     1990         Algeria           25.087818
# 4     1990  American Samoa           27.152000
# ...    ...             ...                 ...
# 5827  2013  Western Sahara           23.744250
# 5828  2013           Yemen           28.129750
# 5829  2013          Zambia           21.196000
# 5830  2013        Zimbabwe           20.710750
# 5831  2013           Åland            6.229750
#
# [5832 rows x 3 columns]
